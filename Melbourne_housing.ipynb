# %% [markdown]
# # Melbourne housing
# Just a exercise for data analyst

# %% [markdown]
# ## Step-1
#
# 1)-Download Melbourne_housing data set from kaggle.
# 2)-Save as Melbourne_housing.csv (file must in the same folder)
# 3)-Run the code below.

# %%
import pandas as pd

melbourne_file_path = '/home/user/Documents/DataAnalyst/Melbourne_housing.csv'
melbourne_data = pd.read_csv(melbourne_file_path) 
melbourne_data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Week', 'CPI', 'LastCPI', 'Distance2'],
#       dtype='object')

# %% [markdown]
# ### if pandas not available. have error. run this code.
#
# pip install pandas

# %%
melbourne_data  #print 5 teratas.
# Out:
#            Suburb             Address Rooms Type    Price Method  \
# 0       Footscray    202/51 Gordon St     1    u    85000     PI
# 1       Caulfield          30 Pyne St     4    h   131000     PI
# 2          Coburg     171 Moreland Rd     4    h   145000     PI
# 3          Albion       8/6 Ridley St     1    u   145000     PI
# 4          Albion  10/117 Anderson Rd     1    u   185000      S
# ...           ...                 ...   ...  ...      ...    ...
# 9378     Armadale    367 Dandenong Rd     6    h  5525000      S
# 9379  South Yarra         18 Avoca St     4    h  5700000      S
# 9380          Kew          7 Wimba Av     5    h  6240000      S
# 9381       Toorak        17 Albany Rd     3    h  6250000      S
# 9382          Kew         15 Barry St     6    h  6500000      S
#
#             SellerG        Date Distance Week    CPI LastCPI Distance2
# 0           Burnham  03-09-2016      6.4   32  108.6   108.2       8.1
# ...

# %%
melbourne_data = melbourne_data.dropna(axis=0)        # dropna drops missing values (think of na as "not available")

# %%
melbourne_data
# Out:
#            Suburb             Address Rooms Type    Price Method  \
# 0       Footscray    202/51 Gordon St     1    u    85000     PI
# 1       Caulfield          30 Pyne St     4    h   131000     PI
# 2          Coburg     171 Moreland Rd     4    h   145000     PI
# 3          Albion       8/6 Ridley St     1    u   145000     PI
# 4          Albion  10/117 Anderson Rd     1    u   185000      S
# ...           ...                 ...   ...  ...      ...    ...
# 9378     Armadale    367 Dandenong Rd     6    h  5525000      S
# 9379  South Yarra         18 Avoca St     4    h  5700000      S
# 9380          Kew          7 Wimba Av     5    h  6240000      S
# 9381       Toorak        17 Albany Rd     3    h  6250000      S
# 9382          Kew         15 Barry St     6    h  6500000      S
#
#             SellerG        Date Distance Week    CPI LastCPI Distance2
# 0           Burnham  03-09-2016      6.4   32  108.6   108.2       8.1
# ...

# %%
# Out:
#            Suburb             Address Rooms  Type   Price Method SellerG  \
# count        9383                9383  9383  9383    9383   9383    9383
# unique        143                8907    11     4    1838      6     195
# top     Reservoir  106/80 Speakmen St     3     h  600000      S  Nelson
# freq          359                   4  3712  5671      85   5959    1181
#
#               Date Distance  Week    CPI LastCPI Distance2
# count         9383     9383  9383   9383    9383      9383
# unique          35       94    35      5       5       276
# top     27-11-2016     11.2    44  108.6   108.2      14.4
# freq           473      767   473   4339    4339       100
